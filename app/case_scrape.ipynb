# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re

date = input("enter date:")
url = "https://dhccaseinfo.nic.in/jsearch/juddt1page.php?dc=31&fflag=1"
data = {'juddt': date, 'Submit': 'Submit'}
home = requests.post(
    url,
    headers={
        'Origin': 'https://dhccaseinfo.nic.in',
        'Content-Type': 'application/x-www-form-urlencoded'
        }, 
    data=data
    )

table = BeautifulSoup(home.content, "html.parser")

raw_case = []
count = 0
for row in table.find_all('tr'):
    row_data = []
    for cell in row.find_all('td'):
        count += 1
        row_data.append(cell.text)
    raw_case.append(row_data)

# %%
df = pd.DataFrame(raw_case)
if (df[1][1]) == ' Information: No Matching record found':
    print(' Information: No Matching record found')
else:
    pattern = r'\d+(?=[A-Za-z\s]*$)'
    records_total = int(re.findall(pattern, df[0][1])[0])

# %%
year = date[-4:]
end_pattern_case = year + ':DHC'

# %%
links = table.find_all('a')
links_arr = []
for link in links:
    if link['href'].startswith('downloadtext'):
        link_full = ("https://dhccaseinfo.nic.in/jsearch/" +link['href'])
        links_arr.append(
            link_full
        )

# %%
df2 = df.iloc[3:, 1:4]

# %%
df2
# Out:
#                                            1
# 3         \nW.P.(C)-17456/2022 2023:DHC:6380  \
# 4          \nW.P.(C)-2857/2023 2023:DHC:6380
# 5   \nFAO(OS) (COMM)-7/2023 2023:DHC:6412-DB
# 6            \nITA-787/2019 2023:DHC:6945-DB
# 7      \nW.P.(C)-11789/2023 2023:DHC:6625-DB
# 8            \nITA-999/2017 2023:DHC:6942-DB
# 9         \nFAO(OS)-94/2023 2023:DHC:6466-DB
# 10     \nW.P.(C)-10079/2023 2023:DHC:6451-DB
# 11     \nW.P.(C)-10527/2023 2023:DHC:6472-DB
# 12       \nW.P.(C)-238/2023 2023:DHC:6528-DB
# 13      \nW.P.(C)-8288/2023 2023:DHC:6672-DB
# 14    \nFAO (COMM)-119/2023 2023:DHC:6452-DB
# 15     \nW.P.(C)-11762/2023 2023:DHC:6393-DB
# 16      \nW.P.(C)-6502/2017 2023:DHC:6453-DB
# 17         \nW.P.(C)-2857/2023 2023:DHC:6374
# 18        \nW.P.(C)-17456/2022 2023:DHC:6463
# 19          \nCO.PET.-539/1998 2023:DHC:6500
# 20        \nW.P.(C)-10683/2022 2023:DHC:6490
# 21        \nW.P.(C)-10867/2022 2023:DHC:6490
# 22         \nCS(COMM)-377/2023 2023:DHC:6479
# 23           \nCM(M)-1051/2022 2023:DHC:6350
# 24          \nMAC.APP.-89/2023 2023:DHC:6469
# 25         \nMAC.APP.-216/2018 2023:DHC:6558
# 26         \nMAC.APP.-698/2018 2023:DHC:6558
# 27         \nCS(COMM)-171/2023 2023:DHC:6465
# 28                                      None
#
#                                      2
# 3                          05-09-2023   \
# 4                          05-09-2023
# 5     05-09-2023(pdf) 05-09-2023 (txt)
# 6     05-09-2023(pdf) 05-09-2023 (txt)
# 7     05-09-2023(pdf) 05-09-2023 (txt)
# 8     05-09-2023(pdf) 05-09-2023 (txt)
# 9     05-09-2023(pdf) 05-09-2023 (txt)
# 10    05-09-2023(pdf) 05-09-2023 (txt)
# 11    05-09-2023(pdf) 05-09-2023 (txt)
# 12    05-09-2023(pdf) 05-09-2023 (txt)
# 13    05-09-2023(pdf) 05-09-2023 (txt)
# 14    05-09-2023(pdf) 05-09-2023 (txt)
# 15    05-09-2023(pdf) 05-09-2023 (txt)
# 16    05-09-2023(pdf) 05-09-2023 (txt)
# 17    05-09-2023(pdf) 05-09-2023 (txt)
# 18    05-09-2023(pdf) 05-09-2023 (txt)
# 19    05-09-2023(pdf) 05-09-2023 (txt)
# 20    05-09-2023(pdf) 05-09-2023 (txt)
# 21  05-09-2023(pdf)  05-09-2023 (txt)
# 22    05-09-2023(pdf) 05-09-2023 (txt)
# 23    05-09-2023(pdf) 05-09-2023 (txt)
# 24    05-09-2023(pdf) 05-09-2023 (txt)
# 25    05-09-2023(pdf) 05-09-2023 (txt)
# 26  05-09-2023(pdf)  05-09-2023 (txt)
# 27    05-09-2023(pdf) 05-09-2023 (txt)
# 28                                None
#
#                                                     3
# 3   DEFSYS SOLUTIONS PRIVATE LIMITED  VsUNION OF I...
# 4   VERT EQUIPMENT PRIVATE LIMITED & ANR.  VsUNION...
# 5   GLOBAL MUSIC JUNCTION PVT. LTD.  VsSHATRUGHAN ...
# 6   THE PR. COMMISSIONER OF INCOME TAX -6  VsMENTO...
# 7   ORION SECURITY SOLUTIONS P. LTD  VsDCIT CIRCLE...
# 8   THE PR. COMMISSIONER OF INCOME TAX -5  VsJUBIL...
# 9       SUSHIL KUMAR SAHDEV  VsKOHLI REALTORS PVT LTD
# 10            MR. AMIT YADAV  VsUNION OF INDIA & ORS.
# 11          YOGESH NATWARIYA  VsUNION OF INDIA & ORS.
# 12  BEST CROP SCIENCE PVT. LTD.  VsSUPERINTENDENT,...
# 13  RAMINDER SINGH  VsASSISSTANT COMMISSIONER OF I...
# 14  GUMBI SOFTWARE PRIVATE LIMITED  VsNATIONAL SKI...
# 15      UNION OF INDIA  & ANR.  VsHARSH SINGH  & ORS.
# 16  SATENDER KUMAR PASWAN & ANR  VsDELHI SUBORDINA...
# 17  VERT EQUIPMENT PRIVATE LIMITED & ANR.  VsUNION...
# 18  DEFSYS SOLUTIONS PRIVATE LIMITED  VsUNION OF I...
# 19  M/S TATA IRON & STEEL CO. LTD.  VsM/S JHALANI ...
# 20  NATIONAL RESTAURANT ASSOCIATION OF INDIA   & O...
# 21  FEDERATION OF HOTEL AND RESTAURANT ASSOCIATION...
# 22  GLAXO GROUP LIMITED AND ANR.  VsMANOJ KUMAR JA...
# 23   OM PRAKASH JAISWAL & ORS.  VsMANISH KUMAR & ORS.
# 24              SANTOSH KUMAR  VsSH. MADAN AND OTHERS
# 25  VIMILA DEVI & ORS  VsSANJAY KUMAR & ORS (VARUN...
# 26  VARUNA INTEGRATED LOGISTICS PVT LTD  VsHDFC ER...
# 27  EMAAR PROPERTIES PJSC  VsEMAARESSE OPC PRIVATE...
# 28                                               None

# %%
for i, link in enumerate(links_arr):
    df2.iloc[i, 1] = link
    index = df2.iloc[i, 0].find(end_pattern_case)
    df2.iloc[i, 0] = df2.iloc[i, 0][1:index]

# %%
df2.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Tamish Sinha\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\range.py:345, in RangeIndex.get_loc(self, key)
#     344 try:
# --> 345     return self._range.index(new_key)
#     346 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [275], line 2
#       1 df2.dropna(inplace=True)
# ----> 2 df2[0]
#
# File c:\Users\Tamish Sinha\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3760, in DataFrame.__getitem__(self, key)
#    3758 if self.columns.nlevels > 1:
#    3759     return self._getitem_multilevel(key)
# -> 3760 indexer = self.columns.get_loc(key)
#    3761 if is_integer(indexer):
#    3762     indexer = [indexer]
#
# File c:\Users\Tamish Sinha\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\range.py:347, in RangeIndex.get_loc(self, key)
#     345         return self._range.index(new_key)
#     346     except ValueError as err:
# --> 347         raise KeyError(key) from err
#     348 self._check_indexing_error(key)
#     349 raise KeyError(key)
#
# KeyError: 0

# %%
df2
# Out:
#                                     1
# 3                 W.P.(C)-17456/2022   \
# 4                  W.P.(C)-2857/2023
# 5              FAO(OS) (COMM)-7/2023
# 6                       ITA-787/2019
# 7                 W.P.(C)-11789/2023
# 8                       ITA-999/2017
# 9                    FAO(OS)-94/2023
# 10                W.P.(C)-10079/2023
# 11                W.P.(C)-10527/2023
# 12                  W.P.(C)-238/2023
# 13                 W.P.(C)-8288/2023
# 14               FAO (COMM)-119/2023
# 15                W.P.(C)-11762/2023
# 16                 W.P.(C)-6502/2017
# 17                 W.P.(C)-2857/2023
# 18                W.P.(C)-17456/2022
# 19                  CO.PET.-539/1998
# 20                W.P.(C)-10683/2022
# 21                W.P.(C)-10867/2022
# 22                 CS(COMM)-377/2023
# 23                   CM(M)-1051/2022
# 24                  MAC.APP.-89/2023
# 25                 MAC.APP.-216/2018
# 26  \nMAC.APP.-698/2018 2023:DHC:6558
# 27  \nCS(COMM)-171/2023 2023:DHC:6465
#
#                                                     2
# 3   https://dhccaseinfo.nic.in/jsearch/downloadtex...  \
# 4   https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 5   https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 6   https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 7   https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 8   https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 9   https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 10  https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 11  https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 12  https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 13  https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 14  https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 15  https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 16  https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 17  https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 18  https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 19  https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 20  https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 21  https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 22  https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 23  https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 24  https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 25  https://dhccaseinfo.nic.in/jsearch/downloadtex...
# 26                 05-09-2023(pdf)  05-09-2023 (txt)
# 27                   05-09-2023(pdf) 05-09-2023 (txt)
#
#                                                     3
# 3   DEFSYS SOLUTIONS PRIVATE LIMITED  VsUNION OF I...
# 4   VERT EQUIPMENT PRIVATE LIMITED & ANR.  VsUNION...
# 5   GLOBAL MUSIC JUNCTION PVT. LTD.  VsSHATRUGHAN ...
# 6   THE PR. COMMISSIONER OF INCOME TAX -6  VsMENTO...
# 7   ORION SECURITY SOLUTIONS P. LTD  VsDCIT CIRCLE...
# 8   THE PR. COMMISSIONER OF INCOME TAX -5  VsJUBIL...
# 9       SUSHIL KUMAR SAHDEV  VsKOHLI REALTORS PVT LTD
# 10            MR. AMIT YADAV  VsUNION OF INDIA & ORS.
# 11          YOGESH NATWARIYA  VsUNION OF INDIA & ORS.
# 12  BEST CROP SCIENCE PVT. LTD.  VsSUPERINTENDENT,...
# 13  RAMINDER SINGH  VsASSISSTANT COMMISSIONER OF I...
# 14  GUMBI SOFTWARE PRIVATE LIMITED  VsNATIONAL SKI...
# 15      UNION OF INDIA  & ANR.  VsHARSH SINGH  & ORS.
# 16  SATENDER KUMAR PASWAN & ANR  VsDELHI SUBORDINA...
# 17  VERT EQUIPMENT PRIVATE LIMITED & ANR.  VsUNION...
# 18  DEFSYS SOLUTIONS PRIVATE LIMITED  VsUNION OF I...
# 19  M/S TATA IRON & STEEL CO. LTD.  VsM/S JHALANI ...
# 20  NATIONAL RESTAURANT ASSOCIATION OF INDIA   & O...
# 21  FEDERATION OF HOTEL AND RESTAURANT ASSOCIATION...
# 22  GLAXO GROUP LIMITED AND ANR.  VsMANOJ KUMAR JA...
# 23   OM PRAKASH JAISWAL & ORS.  VsMANISH KUMAR & ORS.
# 24              SANTOSH KUMAR  VsSH. MADAN AND OTHERS
# 25  VIMILA DEVI & ORS  VsSANJAY KUMAR & ORS (VARUN...
# 26  VARUNA INTEGRATED LOGISTICS PVT LTD  VsHDFC ER...
# 27  EMAAR PROPERTIES PJSC  VsEMAARESSE OPC PRIVATE...
